# %% [markdown]
# ## ต้องลง - conda install pandas- ก่อนที่จะ import pandas
# ## อยู่ใน New -> terminal

# %% [markdown]
# ## ตั้งชื่อในpandas ว่า pd

# %%
import pandas as pd

# %% [markdown]
# ## สร้างตัวแปรเพื่อเก็บไฟล์
# ## PATH คือที่อยู่ของไฟล์
# ## เพิ่ม \ สองอัน

# %%
w_restaurant_PATH = 'C:\\Users\\User\\Desktop\\w_restaurant.csv'
seach_click_PATH = 'C:\\Users\\User\\Desktop\\search_click.csv'

# %% [markdown]
# ## โหลดไฟล์เข้ามา load files into memory สร้างตัวแปรมารับ

# %%
w_restaurant_df = pd.read_csv(w_restaurant_PATH, encoding = 'unicode_escape')
seach_click_df = pd.read_csv(seach_click_PATH, encoding = 'unicode_escape')

# %% [markdown]
# ## เรียกไฟล์มาดูใช้คำสั่ง

# %%
w_restaurant_df
# Out:
#             id                                               name  domain_id  \
# 0            2   à¸à¸à¸£à¸´à¸à¸à¸£à¹à¸à¸±à¸à¸à¸à¸£à¸£à¸¡          2
# 1            4                                       Corner House          1
# 2            5         à¸§à¸±à¸à¹à¸¥à¸à¸¢à¸ªà¸¸à¸à¸²à¸£à¸²à¸¡          4
# 3            6         à¸à¸±à¸à¸à¹à¸à¸²à¸£à¸²à¹à¸­à¹à¸à¸°          1
# 4            7                                        Buono Caffe          1
# ...        ...                                                ...        ...
# 246842  340068                                         Sushi Tama          1
# 246843  340070  à¸ªà¸°à¸à¸²à¸¢à¸à¸µ à¸à¸²à¸£à¸²à¹à¸­à¹à¸à¸°          1
# 246844  340074     à¸ªà¹à¸à¹à¸à¹à¸¡à¹&à¸à¸²à¹à¸à¸¥à¸¹à¸          1
# 246845  340079                                           Mom Made          1
# 246846  340091  à¸à¹à¸§à¸¢à¹à¸à¸µà¹à¸¢à¸§à¸«à¸¡à¸¹à¸à¹à...          1
#
# ...

# %% [markdown]
# ## เรียกไฟล์มาดูใช้คำสั่งเฉพาะหัวตาราง

# %%
seach_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.220000e+15  True
# 1                 0     4.610000e+14  True
# 2                 0     2.580000e+15  True
# 3                 1     1.400000e+15  True
# 4                 1     9.330000e+14  True

# %% [markdown]
# ## เรียกไฟล์มาดูใช้คำสั่งเฉพาะท้ายตาราง

# %%
seach_click_df.tail()
# Out:
#         click_timestamp                             search_id  business_id  \
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads
# 1048570                 8     2.070000e+11  False
# 1048571                 8     6.931413e+10  False
# 1048572                 8     3.105162e+10  False
# 1048573                 8     7.848904e+10  False
# 1048574                 8     3.157757e+10  False

# %% [markdown]
# ## คำสั่งดูรูปร่างตาราง(มีdataกี่ตัว,จำนวนแถว)

# %%
seach_click_df.shape
# Out:
# (1048575, 6)

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ## missing คือที่อยู่ในตารางแล้วไม่มีค่า
# ## คำสั่งนี้จะเข้าไปดูแต่ละช่องว่ามี isnull มั้ย

# %%
w_restaurant_df.isnull()
# Out:
#            id   name  domain_id  closed  city_name  zipcode  geohash  \
# 0       False  False      False   False      False    False    False
# 1       False  False      False   False      False    False    False
# 2       False  False      False   False      False    False    False
# 3       False  False      False   False      False    False    False
# 4       False  False      False   False      False    False    False
# ...       ...    ...        ...     ...        ...      ...      ...
# 246842  False  False      False   False      False    False    False
# 246843  False  False      False   False      False     True    False
# 246844  False  False      False   False      False    False    False
# 246845  False  False      False   False      False    False    False
# 246846  False  False      False   False      False    False    False
#
#         new_open  weighted_average_rating  number_of_chains  ...  \
# 0          False                    False              True  ...
# ...

# %% [markdown]
# ## จะเอาหลักมารวมกันเพื่อให้ดูง่าย

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# ## วิธีจัดการ missing
# ## 1.ตัดออก
# ## 2.แทนค่า missing
# ## 3.หาค่าเฉลี่ยมาเติม

# %% [markdown]
# ## วิธีแก้ แบบ 1.ตัดออก delete with missing value จะลบค่าที่มีmissing ออก
# ## na แปลว่าไม่มีค่า

# %%
w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])
# Out:
#             id                                  name  domain_id  closed  \
# 61         114              à¸¡à¸²à¸à¸µà¸¡à¸µà¸à¸¡          1       0
# 114        224  à¸ªà¹à¸à¹à¸à¸¥à¸¸à¸à¸«à¸à¸§à¸          1       0
# 115        225                              Mr.shake          1       0
# 131        267                                   KFC          1       0
# 140        297                            Miss Mamon          1       1
# ...        ...                                   ...        ...     ...
# 246722  339787                          Chang coffee          1       0
# 246752  339864                              Hokkaido          1       0
# 246815  340000  à¸ªà¹à¸à¹à¸à¸¥à¸¸à¸à¸«à¸à¸§à¸          1       0
# 246834  340048                             Kuppadeli          1       1
# 246842  340068                            Sushi Tama          1       0
#
#                           city_name zipcode  geohash  new_open  \
# ...

# %% [markdown]
# ## หาตัวแปรมารับ

# %%
w_restaurant_df = w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])

# %% [markdown]
# ## 2.แทนค่า missing, fill defauit value to the data

# %% [markdown]
# ## จะเติมค่าที่เป็นmissing ด้วย 0

# %%
w_restaurant_df['parking'].fillna(0)
# Out:
# 61        3.0
# 114       3.0
# 115       0.0
# 131       3.0
# 140       3.0
#          ...
# 246722    1.0
# 246752    3.0
# 246815    3.0
# 246834    0.0
# 246842    3.0
# Name: parking, Length: 13669, dtype: float64

# %% [markdown]
# ## update ข้อมูลในตาราง

# %%
w_restaurant_df['parking'] = w_restaurant_df['parking'].fillna(0)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## วิธีตัดตารางมาเฉพาะบางส่วนของตาราง select part the table by value
# ## ได้listของบุริน

# %% [markdown]
# ### 1.ต้องการร้านที่มีที่จอดรถมากกว่า 5 จะได้ค่า T or F

# %%
w_restaurant_df['parking'] > 5
# Out:
# 61        False
# 114       False
# 115       False
# 131       False
# 140       False
#           ...
# 246722    False
# 246752    False
# 246815    False
# 246834    False
# 246842    False
# Name: parking, Length: 13669, dtype: bool

# %% [markdown]
# ## 2.เลือกค่าในตาราง

# %% [markdown]
# ## part of table = table[data_condition == True]

# %%
w_restaurant_df[w_restaurant_df['parking']>=3]
# Out:
#             id                                  name  domain_id  closed  \
# 61         114              à¸¡à¸²à¸à¸µà¸¡à¸µà¸à¸¡          1       0
# 114        224  à¸ªà¹à¸à¹à¸à¸¥à¸¸à¸à¸«à¸à¸§à¸          1       0
# 131        267                                   KFC          1       0
# 140        297                            Miss Mamon          1       1
# 149        344                       Inthanin Coffee          1       0
# ...        ...                                   ...        ...     ...
# 246646  339670       Four Seasons Chinese Restaurant          1       0
# 246684  339718                          Jeffer Steak          1       0
# 246752  339864                              Hokkaido          1       0
# 246815  340000  à¸ªà¹à¸à¹à¸à¸¥à¸¸à¸à¸«à¸à¸§à¸          1       0
# 246842  340068                            Sushi Tama          1       0
#
#                           city_name zipcode  geohash  new_open  \
# ...

# %% [markdown]
# ## HW select all restaurants from your hometown เลือกจังหวัดของตนเอง

# %%
w_restaurant_df = pd.read_csv(w_restaurant_PATH ,encoding = 'unicode_escape')

# %%
set(w_restaurant_df['city_name'])
# Out:
# {'Abu Dhabi',
#  'Aichi-ken',
#  'Akershus',
#  'Akita-ken',
#  'Al Farwaniyah Governorate',
#  'Alabama',
#  'Alaska',
#  'Alberta',
#  'Amnat Charoen',
#  'AndalucÃ\xada',
#  'Ang Thong',
#  'Aomori-ken',
#  'Appenzell Ausserrhoden',
#  'Appenzell Innerrhoden',
#  'AragÃ³n',
#  'Argyll and Bute',
#  'Arizona',
#  'Attica',
#  'Auckland',
#  'Australia',
#  'Auvergne-RhÃ´ne-Alpes',
#  'AydÄ±n',
#  'Ba Ria - Vung Tau',
#  'Baden-Wurttemberg',
#  'Bago Region',
#  'Bahia',
#  'Bali',
#  'Balochistan',
#  'Bangkok Metropolitan Region',
#  'Banteay Meanchey Province',
#  'Banten',
#  'Basel-Stadt',
#  'Basilicata',
#  'Basrah',
#  'Battambang',
#  'Bay Of Plenty',
#  'Bayern',
#  'Berlin',
#  'Bern',
#  'Bihar',
#  'Binh Thuan',
#  'Binh Thuan province',
#  'Borno',
#  'Bratislava',
#  'Bremen',
#  'Bretagne',
#  'British Columbia',
#  'Brussels Hoofdstedelijk Gewest',
#  'Buckinghamshire',
#  'Budapest',
#  'Bueng Kan',
#  'Buri Ram',
#  'Busan',
#  'Buskerud',
#  'C2 MALL',
# ...

# %%
 w_restaurant_df[w_restaurant_df['city_name']] = 'Khon Kaen'

# %%
w_restaurant_df['name']
# Out:
# 0          à¸à¸à¸£à¸´à¸à¸à¸£à¹à¸à¸±à¸à¸à¸à¸£à¸£à¸¡
# 1                                              Corner House
# 2                à¸§à¸±à¸à¹à¸¥à¸à¸¢à¸ªà¸¸à¸à¸²à¸£à¸²à¸¡
# 3                à¸à¸±à¸à¸à¹à¸à¸²à¸£à¸²à¹à¸­à¹à¸à¸°
# 4                                               Buono Caffe
#                                 ...
# 246842                                           Sushi Tama
# 246843    à¸ªà¸°à¸à¸²à¸¢à¸à¸µ à¸à¸²à¸£à¸²à¹à¸­à¹à¸à¸°
# 246844       à¸ªà¹à¸à¹à¸à¹à¸¡à¹&à¸à¸²à¹à¸à¸¥à¸¹à¸
# 246845                                             Mom Made
# 246846    à¸à¹à¸§à¸¢à¹à¸à¸µà¹à¸¢à¸§à¸«à¸¡à¸¹à¸à¹à...
# Name: name, Length: 246847, dtype: object

# %%
w_restaurant_df[w_restaurant_df['City_name'] = 'Khon Kaen']
# Out:
#   File "<ipython-input-20-92259491f9d5>", line 1
#     w_restaurant_df[w_restaurant_df['City_name'] = 'Khon Kaen']
#                                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## save table to a file

# %%
w_restaurant_df.to_csv('test.csv')
