# %%
import pandas
import numpy as np

# %%
covrona_df1 = pandas.read_csv('C:\\Users\\User\\Desktop\\covid_19_data.csv',header = 0)
covrona_df1
# Out:
#        SNo ObservationDate                Province/State  \
# 0        1      01/22/2020                         Anhui
# 1        2      01/22/2020                       Beijing
# 2        3      01/22/2020                     Chongqing
# 3        4      01/22/2020                        Fujian
# 4        5      01/22/2020                         Gansu
# ...    ...             ...                           ...
# 6157  6158      03/16/2020                Cayman Islands
# 6158  6159      03/16/2020                     Gibraltar
# 6159  6160      03/16/2020  Diamond Princess cruise ship
# 6160  6161      03/16/2020                 West Virginia
# 6161  6162      03/16/2020                           NaN
#
#                       Country/Region          Last Update  Confirmed  Deaths  \
# 0                     Mainland China      1/22/2020 17:00          1       0
# 1                     Mainland China      1/22/2020 17:00         14       0
# ...

# %%
covrona_df1.dropna(subset = ['Province/State'])
# Out:
#        SNo ObservationDate                Province/State  Country/Region  \
# 0        1      01/22/2020                         Anhui  Mainland China
# 1        2      01/22/2020                       Beijing  Mainland China
# 2        3      01/22/2020                     Chongqing  Mainland China
# 3        4      01/22/2020                        Fujian  Mainland China
# 4        5      01/22/2020                         Gansu  Mainland China
# ...    ...             ...                           ...             ...
# 6156  6157      03/16/2020                Virgin Islands              US
# 6157  6158      03/16/2020                Cayman Islands              UK
# 6158  6159      03/16/2020                     Gibraltar              UK
# 6159  6160      03/16/2020  Diamond Princess cruise ship       Australia
# 6160  6161      03/16/2020                 West Virginia              US
#
#               Last Update  Confirmed  Deaths  Recovered
# ...

# %%
covrona_df1
# Out:
#        SNo ObservationDate                Province/State  \
# 0        1      01/22/2020                         Anhui
# 1        2      01/22/2020                       Beijing
# 2        3      01/22/2020                     Chongqing
# 3        4      01/22/2020                        Fujian
# 4        5      01/22/2020                         Gansu
# ...    ...             ...                           ...
# 6157  6158      03/16/2020                Cayman Islands
# 6158  6159      03/16/2020                     Gibraltar
# 6159  6160      03/16/2020  Diamond Princess cruise ship
# 6160  6161      03/16/2020                 West Virginia
# 6161  6162      03/16/2020                           NaN
#
#                       Country/Region          Last Update  Confirmed  Deaths  \
# 0                     Mainland China      1/22/2020 17:00          1       0
# 1                     Mainland China      1/22/2020 17:00         14       0
# ...

# %%
df = covrona_df1[['Province/State','Confirmed','Deaths','Recovered']]

# %%
df
# Out:
#                     Province/State  Confirmed  Deaths  Recovered
# 0                            Anhui          1       0          0
# 1                          Beijing         14       0          0
# 2                        Chongqing          6       0          0
# 3                           Fujian          1       0          0
# 4                            Gansu          0       0          0
# ...                            ...        ...     ...        ...
# 6157                Cayman Islands          1       1          0
# 6158                     Gibraltar          1       0          1
# 6159  Diamond Princess cruise ship          0       0          0
# 6160                 West Virginia          0       0          0
# 6161                           NaN          0       0          0
#
# [6162 rows x 4 columns]

# %%
df_n = df.groupby('Province/State').mean().reset_index()

# %%
df_n = df.groupby('Province/State').reset_index()

# %%
import pandas
import numpy as np

# %%
covrona_df1 = pandas.read_csv('C:\\Users\\User\\Desktop\\covid_19_data.csv',header = 0)
covrona_df1
# Out:
#        SNo ObservationDate                Province/State  \
# 0        1      01/22/2020                         Anhui
# 1        2      01/22/2020                       Beijing
# 2        3      01/22/2020                     Chongqing
# 3        4      01/22/2020                        Fujian
# 4        5      01/22/2020                         Gansu
# ...    ...             ...                           ...
# 6157  6158      03/16/2020                Cayman Islands
# 6158  6159      03/16/2020                     Gibraltar
# 6159  6160      03/16/2020  Diamond Princess cruise ship
# 6160  6161      03/16/2020                 West Virginia
# 6161  6162      03/16/2020                           NaN
#
#                       Country/Region          Last Update  Confirmed  Deaths  \
# 0                     Mainland China      1/22/2020 17:00          1       0
# 1                     Mainland China      1/22/2020 17:00         14       0
# ...

# %%
time=covrona_df1[['Last Update']]
time
# Out:
#               Last Update
# 0         1/22/2020 17:00
# 1         1/22/2020 17:00
# 2         1/22/2020 17:00
# 3         1/22/2020 17:00
# 4         1/22/2020 17:00
# ...                   ...
# 6157  2020-03-16T14:53:04
# 6158  2020-03-14T16:33:03
# 6159  2020-03-14T02:33:04
# 6160  2020-03-10T02:33:04
# 6161  2020-03-11T20:53:02
#
# [6162 rows x 1 columns]

# %%
df_new2 = datacov_n.groupby(['Country/Region','Province/State']).mean().reset_index()
