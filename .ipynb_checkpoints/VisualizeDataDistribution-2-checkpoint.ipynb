# %% [markdown]
# # Box plot

# %%
import pandas
import numpy as np #ตัวเลขโดนเฉพาะ|

# %%
from matplotlib import pyplot as plt
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy()
versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()
virginica_np = irisdata.iloc[100:,:-1].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4d5a0c652656> in <module>
# ----> 1 setosa_np = irisdata.iloc[:50,:-1].to_numpy()
#       2 versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()
#       3 virginica_np = irisdata.iloc[100:,:-1].to_numpy()
#
# NameError: name 'irisdata' is not defined

# %%
matplotlib.rcParams['figure.figsize'] = [12,12]
plt.subplot(1,4,1)
plt.boxplot(setosa_np[:,0])
plt.subplot(1,4,2)
plt.boxplot(setosa_np[:,1])
plt.subplot(1,4,3)
plt.boxplot(setosa_np[:,2])
plt.subplot(1,4,4)
plt.boxplot(setosa_np[:,3])
plt.show()

# %%
setosa_np.shape

# %%
plt.boxplot(setosa_np[:,0])

# %%
plt.boxplot(setosa_np)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x90e9a58>,
#   <matplotlib.lines.Line2D at 0x90e9e10>,
#   <matplotlib.lines.Line2D at 0x90edf98>,
#   <matplotlib.lines.Line2D at 0x95a2588>,
#   <matplotlib.lines.Line2D at 0x95a5978>,
#   <matplotlib.lines.Line2D at 0x95a5cc0>,
#   <matplotlib.lines.Line2D at 0x9588e48>,
#   <matplotlib.lines.Line2D at 0x9580438>],
#  'caps': [<matplotlib.lines.Line2D at 0x90e9ef0>,
#   <matplotlib.lines.Line2D at 0x90ed4e0>,
#   <matplotlib.lines.Line2D at 0x95a28d0>,
#   <matplotlib.lines.Line2D at 0x95a2c18>,
#   <matplotlib.lines.Line2D at 0x95a5da0>,
#   <matplotlib.lines.Line2D at 0x9588390>,
#   <matplotlib.lines.Line2D at 0x9580780>,
#   <matplotlib.lines.Line2D at 0x9580ac8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x90e9668>,
#   <matplotlib.lines.Line2D at 0x90edeb8>,
#   <matplotlib.lines.Line2D at 0x95a5630>,
#   <matplotlib.lines.Line2D at 0x9588d68>],
#  'medians': [<matplotlib.lines.Line2D at 0x90ed828>,
#   <matplotlib.lines.Line2D at 0x95a2f60>,
#   <matplotlib.lines.Line2D at 0x95886d8>,
#   <matplotlib.lines.Line2D at 0x9580e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x90edb70>,
#   <matplotlib.lines.Line2D at 0x95a2ef0>,
#   <matplotlib.lines.Line2D at 0x9588a20>,
#   <matplotlib.lines.Line2D at 0x9580ef0>],
#  'means': []}

# %% [markdown]
# # HW

# %%
import numpy as np

# %%
f1 = [setosa_np[:,0],versicolor_np[:,0],virginica_np[:,0]]

# %%
f1
# Out:
# [array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. ]),
#  array([7. , 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. ,
#         6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6,
#         6.8, 6.7, 6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6,
#         5.5, 5.5, 6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7]),
#  array([6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8,
#         5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2,
#         6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. ,
#         6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])]

# %%
plt.boxplot(f1);

# %%
plt.boxplot(f1)   #เปลี่ยนชื่อกราฟ
plt.title('Feature 1 Comparison');  #ใส่,เพื่อไม่ให้มีคำอธิบายแท้กเอ้าพุท

# %%
plt.boxplot(f1,labels=['setosa_np','versicolor_np','virginica_np']) 
plt.title('Feature 1 Comparison');

# %% [markdown]
# # Bubble Chart
# # คือการใช้ขนาดของวงกลมแสดงค่าของdata

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=1000*setosa_np[:,2],c = 'k')

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=1000*setosa_np[:,2],c = 'k',alpha = 0.2)    #ลดขนาดความทึบของสี

# %% [markdown]
# # HW

# %%
ls #ดูว่ามีไฟลือะไรอยู่ในแฟ้มบ้าง
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2E64-A9EF
#
#  Directory of C:\Users\Administrator\Desktop\Basicprogramming\python_dataviz
#
# 02/21/2020  03:25 PM    <DIR>          .
# 02/21/2020  03:25 PM    <DIR>          ..
# 01/24/2020  01:19 PM                77 .gitignore
# 02/21/2020  01:19 PM    <DIR>          .ipynb_checkpoints
# 01/21/2020  05:51 PM           116,837 01.png
# 01/21/2020  05:52 PM           102,485 02.png
# 01/05/2020  07:20 AM           105,364 anaconda1.jpg
# 01/05/2020  11:51 AM            23,167 anaconda10.jpg
# 01/05/2020  11:52 AM           170,420 anaconda11.jpg
# 01/05/2020  11:52 AM           252,523 anaconda12.jpg
# 01/05/2020  11:53 AM           280,091 anaconda13.jpg
# 01/05/2020  12:02 PM           389,363 anaconda14.jpg
# 01/05/2020  12:04 PM           120,977 anaconda15.jpg
# 01/05/2020  12:04 PM            39,050 anaconda16.jpg
# 01/05/2020  12:05 PM            41,233 anaconda17.jpg
# 01/05/2020  12:05 PM            53,432 anaconda18.jpg
# 01/05/2020  12:06 PM            59,197 anaconda19.jpg
# 01/05/2020  07:21 AM           107,203 anaconda2.jpg
# 01/05/2020  12:06 PM            59,116 anaconda20.jpg
# 01/05/2020  01:44 PM            61,916 visual8.jpg
# 01/05/2020  01:47 PM            80,066 visual9.jpg
# 01/24/2020  03:30 PM            90,256 Visualiza array data.ipynb
# 02/14/2020  03:49 PM           609,992 VisualizeDataDistribution.ipynb
# 02/21/2020  03:25 PM           215,088 VisualizeDataDistribution2.ipynb
#               76 File(s)     43,881,652 bytes
#                3 Dir(s)  18,287,468,544 bytes free

# %%
import pandas

# %%
Debt = 'Average Debt.xls'

# %%
Debt_df=pandas.read_excel(Debt)

# %%
Debt_df=pandas.read_excel(Debt,skiprows=3)    #ข้าม3บรรทัดบน

# %%
Debt_df
# Out:
#           ภาค และจังหวัด                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2        ทั่วราชอาณาจักร                                                NaN
# 3               ตอนพิเศษ                                                NaN
# 4          กรุงเทพมหานคร                                                NaN
# ..                   ...                                                ...
# 84              นราธิวาส                                                NaN
# 85                   NaN                                                NaN
# 86                   NaN                                                NaN
# 87                ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88               Source:  The Household Socio - Economic Survey, Nationa...
#
#         2541      2543      2545      2547      2549      2550      2552  \
# 0     1998.0    2000.0    2002.0    2004.0    2006.0    2007.0    2009.0
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2    69674.0   68405.0   82485.0  104571.0  116585.0  116681.0  134699.3
# 3   131740.0  126527.0  157730.0  155622.0  155212.0  151168.0  199608.1
# 4   138247.0  135137.0  162199.0  160776.0  158059.0  155396.0  207665.0
# ..       ...       ...       ...       ...       ...       ...       ...
# 84   25071.0   15087.0   34023.0   39297.0   57235.0   36368.0   26246.4
# 85       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 86       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 87       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 88       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         2554      2556           2558    Region and province
# 0     2011.0    2013.0    2015.000000                    NaN
# 1        NaN       NaN            NaN                    NaN
# 2   134899.9  163087.0  156770.455510          Whole Kingdom
# 3   202157.2  273795.0  171837.386694        Greater Bangkok
# 4   218741.4  275576.8  164705.600000                Bangkok
# ..       ...       ...            ...                    ...
# 84   40942.5   44974.1   40566.900000             Narathiwat
# 85       NaN       NaN            NaN                    NaN
# 86       NaN       NaN            NaN                    NaN
# 87       NaN       NaN            NaN                    NaN
# 88       NaN       NaN            NaN                    NaN
#
# [89 rows x 13 columns]

# %%
Debt_df[['Region and province',2549]]   #เลือกคอลัมน์ที่เราสนใจ
# Out:
#       Region and province      2549
# 0                     NaN    2006.0
# 1                     NaN       NaN
# 2           Whole Kingdom  116585.0
# 3         Greater Bangkok  155212.0
# 4                 Bangkok  158059.0
# ..                    ...       ...
# 84             Narathiwat   57235.0
# 85                    NaN       NaN
# 86                    NaN       NaN
# 87                    NaN       NaN
# 88                    NaN       NaN
#
# [89 rows x 2 columns]

# %%
Debt_df_debt=Debt_df[['Region and province',2549]]  #ทำการตั้งชื่อข้อมูลใหม่เพื่อเอาไว้เก็บข้อมูลที่เราทำการลบออกไปแล้ว เหลือแค่ที่เราต้องการพร้อมสำหรับการใช้งาน

# %%
Debt_df_debt.drop([0,1,2,3,8,31,49,70,85,86,87,88],axis=0,inplace=True)   #ทำการลบแถวที่ไม่เกี่ยวข้องออกไป
# Out:
# C:\Program Files\anacon\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Debt_df_debt
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# ..                                  ...       ...
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
Debt_df_debt.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
import folium      #ทำการimport folium เพื่อใช้สำหรับการทำแผนที่
import pandas as pd

# %%
data_to_plot=Debt_df_debt

# %%
data_to_plot
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# ..                                  ...       ...
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
data_to_plot.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
## ทำแผนที่

# %%
country_geo = 'thai.json'

# %%
new_col=list()
for d in data_to_plot['Region and province']:
      new_col.append(d.lstrip())
data_to_plot['Region and province']=new_col         #ทำการDownloadข้อมูลเชิงภูมิศาสตร์ของประเทศไทยจากเว็บไซต์และทำการลบช่องว่างข้างหน้าชื่อออกเพื่อที่จะสามารถทำให้ไฟล์ 2 ไฟล์นั้นสามารถเชื่อมกันได้
# Out:
# C:\Program Files\anacon\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
map = folium.Map(location=[10,100],zoom_start=5)   #ทำการกำหนดพิกัด ลองติจูดและละติจูดของประเทศไทย

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.choropleth(geo_data=country_geo,data=data_to_plot,
              columns=['Region and province',2549],
              key_on='feature.properties.name',
              fill_color='YlGnBu',fill_opacity=0.7,line_opacity=0.2,
              legend_name='Average Debt')                                     #ทำการลงสีของข้อมูลที่มีค่าของจำนวนหนี้สินเฉลี่ยต่อครัวเรือนถ้าจังหวัดไหนที่มีจำนวนหนี้สินเฉลี่ยต่อครัวเรือนมีค่ามากจะเป็นสีม่วงเข้มส่วนจังหวัดไหนที่มีจำนวนหนี้สินเฉลี่ยต่อครัวเรือนน้อยจะเป็นสีเหลืองตามแถบรูปข้างบน

# %%
map.save('plot_data.html')

# %%
from IPython.display import HTML
HTML('<iframe src=plot_data.html width=450 height=700></iframe>')
# Out:
# <iframe src=plot_data.html width=450 height=700></iframe>
